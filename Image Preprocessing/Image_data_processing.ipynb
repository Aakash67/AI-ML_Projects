# %% [markdown]
# ### Image data processing in Deep Learning
#
#
#
# 1.   Image Dimension (Height * Width = Total Pixels)
# 2.   Image Resolution
# 3. Types of Images (Grey Scale(1 Channel), RGB Image(3 channels(Red,Green,Blue)))

# %% [markdown]
# ### Processing Grey Scale Images
# ![picture](data:image/jpeg;base64,...)
# 1. Coverting the grey scale into a numerical matrix
#
# * Range of grey scale matrix (0-255)
#
#
# ```
# 0 ----> Black
# 255 ----> White
# ```

# %% [markdown]
# ### Processing the RGB Images
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRWrv1hG97Ep_so_JAUOKDJdSxDvbryCpjqsVl1GSplx6dvNKGbpyPIlKfAIS7cByIKuSg&usqp=CAU)
#
# 1.   Represented in 3 different matrix (Red,Green,Blue)
#
# ![picture](data:image/png;base64,...)

# %% [markdown]
# # Initial Preprocessing steps
#
#
#
# 1.   Reading the Image file converting them into numpy array
# 2.   Resizing an image
# 3.   RGB to GrayScale Conversion

# %%
#Getting the image using web get

# !wget 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQHkmbaje8L3Wm4ZrY4YfcA4aROaTGH6nwfXQ&usqp=CAU'
# Out:
# --2023-08-08 05:42:33--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQHkmbaje8L3Wm4ZrY4YfcA4aROaTGH6nwfXQ&usqp=CAU
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 74.125.128.100, 74.125.128.138, 74.125.128.102, ...
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|74.125.128.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6147 (6.0K) [image/jpeg]
# Saving to: ‘images?q=tbn:ANd9GcQHkmbaje8L3Wm4ZrY4YfcA4aROaTGH6nwfXQ&usqp=CAU.1’
#
# images?q=tbn:ANd9Gc 100%[===================>]   6.00K  --.-KB/s    in 0s
#
# 2023-08-08 05:42:33 (70.5 MB/s) - ‘images?q=tbn:ANd9GcQHkmbaje8L3Wm4ZrY4YfcA4aROaTGH6nwfXQ&usqp=CAU.1’ saved [6147/6147]

# %% [markdown]
# **Libaraies that can be used for image processing**
# 1. Matplotlib.image
# 2. Pillow
# 3. OpenCV(cv2)

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# Loading the image through matplotlib.image module

img = mpimg.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (183, 275, 3)

# %% [markdown]
# ( Height, Widgth, No of channels )

# %%
print(img)
# Out:
# [[[135 182  18]
#   [137 182  17]
#   [142 186  15]
#   ...
#   [130 149   0]
#   [129 149   0]
#   [129 149   0]]
#
#  [[127 172   7]
#   [126 172   4]
#   [130 172   2]
#   ...
#   [132 151   0]
#   [131 151   0]
#   [131 151   0]]
#
#  [[129 173   2]
#   [126 168   0]
#   [121 164   0]
#   ...
#   [134 153   0]
#   [134 153   2]
#   [134 153   2]]
#
#  ...
#
#  [[ 69  58  28]
#   [ 62  53  20]
#   [ 54  43  11]
#   ...
#   [127 104  37]
#   [128 104  34]
#   [128 104  34]]
#
#  [[ 67  58  27]
#   [ 60  54  20]
#   [ 56  47  14]
#   ...
#   [128 105  38]
#   [129 105  35]
#   [129 105  35]]
#
#  [[ 63  57  25]
#   [ 60  56  21]
#   [ 59  53  19]
#   ...
#   [128 105  38]
#   [129 105  35]
#   [130 106  36]]]

# %% [markdown]
# ### Converting numpy array into Image

# %%
img_plot = plt.imshow(img)

# %% [markdown]
# ## Resizing the images using pillow library

# %%
from PIL import Image

# %%
img = Image.open('/content/dog.jpg')
img_resized = img.resize((100,100))

# %%
img_resized.save('dog_img_resized.jpg')

# %%
img_res = mpimg.imread('/content/dog_img_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
img_res.shape
# Out:
# (100, 100, 3)

# %% [markdown]
# ### Converting RGB image to RGB to GreyScale using OpenCV

# %%
import cv2

# %%
img = cv2.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (183, 275, 3)

# %%
g_img = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
g_img.shape
# Out:
# (183, 275)

# %% [markdown]
# cv2.imshow() will display the image but this will not be allowed in Google Collab
#
# Alter:
# `from google.colab.patches import cv2_imshow`

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(g_img)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
cv2.imwrite('doggreyscale.jpg',g_img)
# Out:
# True
